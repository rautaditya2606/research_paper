# %% [markdown]
# # Leaky Dataset Pipeline
# Uses the original dataset split as-is (train/valid/test from `data/`).
# This reproduces the inflated benchmark — the baseline to compare against.

# %% [markdown]
# ## 1. Imports & Config

# %%
import os
import re
import time
import copy
import json
import tracemalloc
from pathlib import Path
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from torchvision.datasets import ImageFolder

from sklearn.metrics import (
    confusion_matrix, classification_report,
    f1_score, precision_score, recall_score, roc_auc_score
)
from sklearn.preprocessing import label_binarize

import onnx
import onnxruntime as ort
from torch.quantization import quantize_dynamic

# ── Paths ──────────────────────────────────────────────────────────────────
BASE_DIR     = Path('/home/adityaraut/Documents/research_paper')
DATA_DIR     = BASE_DIR / 'data'
LEAKY_DIR    = BASE_DIR / 'leaky'

SAVE_DIRS = {
    'resnet50':        LEAKY_DIR / 'resnet_leaky',
    'mobilenet_v3_small': LEAKY_DIR / 'mnv3_small_leaky',
    'mobilenet_v3_large': LEAKY_DIR / 'mnv3_large_leaky',
    'efficientnet_b0': LEAKY_DIR / 'efn_leaky',
}

# ── Hyperparameters ────────────────────────────────────────────────────────
BATCH_SIZE   = 32
EPOCHS       = 30
LR           = 1e-4
FREEZE_EPOCHS = 5      # freeze backbone for first N epochs
NUM_CLASSES  = 15
IMG_SIZE     = 224
VARIANT      = 'leaky'

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')
if DEVICE.type == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
# Out:
# Device: cuda
# GPU: NVIDIA GeForce RTX 3050 4GB Laptop GPU
# VRAM: 4.0 GB

# %% [markdown]
# ## 2. Class Name Normalisation

# %%
def normalize_class_name(folder_name: str) -> str:
    """Strip split suffixes, lowercase, underscores.
    Handles: 'Aphid', 'aphid_test', 'aphid_valid', 'blast_test_valid'
    """
    name = re.sub(r'_(test_valid|test|valid)$', '', folder_name)
    return name.lower().replace(' ', '_')


def build_class_map(split_dir: Path):
    """Returns (folder→idx dict, idx→canonical_name list)."""
    folders = sorted([d.name for d in split_dir.iterdir() if d.is_dir()])
    canonical = sorted(set(normalize_class_name(f) for f in folders))
    class_to_idx = {f: canonical.index(normalize_class_name(f)) for f in folders}
    return class_to_idx, canonical


# Build from train (most complete set of class names)
FOLDER_TO_IDX, CLASS_NAMES = build_class_map(DATA_DIR / 'train')
print('Classes:', CLASS_NAMES)
print('Total classes:', len(CLASS_NAMES))
# Out:
# Classes: ['aphid', 'black_rust', 'blast', 'brown_rust', 'common_root_rot', 'fusarium_head_blight', 'healthy', 'leaf_blight', 'mildew', 'mite', 'septoria', 'smut', 'stem_fly', 'tan_spot', 'yellow_rust']
# Total classes: 15

# %% [markdown]
# ## 3. Dataset & Class Distribution

# %%
class WheatDiseaseDataset(Dataset):
    EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}

    def __init__(self, split_dir: Path, folder_to_idx: dict, transform=None):
        self.transform = transform
        self.samples   = []   # (path, label_idx)

        for folder, idx in folder_to_idx.items():
            folder_path = split_dir / folder
            if not folder_path.exists():
                continue
            for f in folder_path.iterdir():
                if f.suffix.lower() in self.EXTENSIONS:
                    self.samples.append((f, idx))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        img = Image.open(path).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, label


# ── Quick count before transforms ─────────────────────────────────────────
raw_train = WheatDiseaseDataset(DATA_DIR / 'train', FOLDER_TO_IDX)
counts = np.zeros(NUM_CLASSES, dtype=int)
for _, lbl in raw_train.samples:
    counts[lbl] += 1

# Plot
fig, ax = plt.subplots(figsize=(14, 5))
bars = ax.bar(CLASS_NAMES, counts, color='steelblue', edgecolor='white')
ax.set_title('Training Set Class Distribution (Leaky)', fontsize=14)
ax.set_ylabel('Image Count')
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=9)
for bar, c in zip(bars, counts):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10,
            str(c), ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt.savefig(LEAKY_DIR / 'class_distribution.png', dpi=150)
plt.show()

print(f'Total train images : {counts.sum()}')
print(f'Max class          : {CLASS_NAMES[counts.argmax()]} ({counts.max()})')
print(f'Min class          : {CLASS_NAMES[counts.argmin()]} ({counts.min()})')
print(f'Imbalance ratio    : {counts.max()/counts.min():.2f}x')
# Out:
# /tmp/ipykernel_5383/563985914.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=9)
# Total train images : 13104
# Max class          : smut (1310)
# Min class          : stem_fly (234)
# Imbalance ratio    : 5.60x

# %% [markdown]
# ## 4. Transforms & DataLoaders

# %%
# ── Transforms ─────────────────────────────────────────────────────────────
MEAN = [0.485, 0.456, 0.406]
STD  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD),
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD),
])

# ── Datasets ───────────────────────────────────────────────────────────────
# Build separate maps for each split to handle different folder naming conventions
train_folder_to_idx, CLASS_NAMES = build_class_map(DATA_DIR / 'train')
val_folder_to_idx,   _           = build_class_map(DATA_DIR / 'valid')
test_folder_to_idx,  _           = build_class_map(DATA_DIR / 'test')

train_ds = WheatDiseaseDataset(DATA_DIR / 'train', train_folder_to_idx, train_transform)
val_ds   = WheatDiseaseDataset(DATA_DIR / 'valid', val_folder_to_idx,   val_transform)
test_ds  = WheatDiseaseDataset(DATA_DIR / 'test',  test_folder_to_idx,  val_transform)

# ── Class weights ──────────────────────────────────────────────────────────
class_weights = torch.tensor(
    len(train_ds) / (NUM_CLASSES * counts.astype(float)),
    dtype=torch.float32
).to(DEVICE)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=4, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=4, pin_memory=True)

print(f'Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}')
print(f'Class weights: {class_weights.cpu().numpy().round(3)}')
# Out:
# Train: 13104 | Val: 300 | Test: 750
# Class weights: [0.967 1.517 1.35  0.687 1.423 1.43  0.874 1.038 0.808 1.092 0.764 0.667
#  3.733 1.135 0.671]

# %% [markdown]
# ## 5. Model Factory

# %%
def get_model(name: str, num_classes: int) -> nn.Module:
    """Load pretrained model, replace classifier head."""
    if name == 'resnet50':
        m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
        m.fc = nn.Linear(m.fc.in_features, num_classes)

    elif name == 'mobilenet_v3_small':
        m = models.mobilenet_v3_small(weights=models.MobileNet_V3_Small_Weights.IMAGENET1K_V1)
        m.classifier[-1] = nn.Linear(m.classifier[-1].in_features, num_classes)

    elif name == 'mobilenet_v3_large':
        m = models.mobilenet_v3_large(weights=models.MobileNet_V3_Large_Weights.IMAGENET1K_V1)
        m.classifier[-1] = nn.Linear(m.classifier[-1].in_features, num_classes)

    elif name == 'efficientnet_b0':
        m = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
        m.classifier[-1] = nn.Linear(m.classifier[-1].in_features, num_classes)

    else:
        raise ValueError(f'Unknown model: {name}')

    return m


def freeze_backbone(model: nn.Module, name: str):
    """Freeze all layers except the final classifier head."""
    if name == 'resnet50':
        for p in model.parameters(): p.requires_grad = False
        for p in model.fc.parameters(): p.requires_grad = True
    elif name in ('mobilenet_v3_small', 'mobilenet_v3_large'):
        for p in model.parameters(): p.requires_grad = False
        for p in model.classifier.parameters(): p.requires_grad = True
    elif name == 'efficientnet_b0':
        for p in model.parameters(): p.requires_grad = False
        for p in model.classifier.parameters(): p.requires_grad = True


def unfreeze_all(model: nn.Module):
    for p in model.parameters():
        p.requires_grad = True


MODEL_NAMES = ['resnet50', 'mobilenet_v3_small', 'mobilenet_v3_large', 'efficientnet_b0']

# param counts
for name in MODEL_NAMES:
    m = get_model(name, NUM_CLASSES)
    total = sum(p.numel() for p in m.parameters()) / 1e6
    print(f'{name:<25} {total:.2f}M params')
# Out:
# resnet50                  23.54M params
# mobilenet_v3_small        1.53M params
# mobilenet_v3_large        4.22M params
# efficientnet_b0           4.03M params

# %% [markdown]
# ## 6. Training Loop

# %%
def train_model(model_name: str):
    save_dir = SAVE_DIRS[model_name]
    save_dir.mkdir(parents=True, exist_ok=True)

    log_path  = save_dir / f'{model_name}_{VARIANT}_metrics.txt'
    ckpt_path = save_dir / f'{model_name}_{VARIANT}.pth'

    model = get_model(model_name, NUM_CLASSES).to(DEVICE)
    freeze_backbone(model, model_name)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=LR)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

    best_val_acc = 0.0
    best_weights = None
    history = []

    log_lines = [
        f'Model      : {model_name}',
        f'Variant    : {VARIANT}',
        f'Epochs     : {EPOCHS}',
        f'Batch size : {BATCH_SIZE}',
        f'LR         : {LR}',
        f'Device     : {DEVICE}',
        f'Started    : {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}',
        '-' * 70,
        f'{"Epoch":<8}{"Train Loss":<14}{"Val Loss":<14}{"Val Acc":<12}{"LR"}',
        '-' * 70,
    ]

    print(f'\n{"="*60}')
    print(f'Training: {model_name.upper()} [{VARIANT}]')
    print(f'{"="*60}')

    for epoch in range(1, EPOCHS + 1):
        # unfreeze backbone after FREEZE_EPOCHS
        if epoch == FREEZE_EPOCHS + 1:
            unfreeze_all(model)
            optimizer = optim.AdamW(model.parameters(), lr=LR)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=EPOCHS - FREEZE_EPOCHS
            )
            print(f'  [Epoch {epoch}] Backbone unfrozen.')

        # ── Train ──────────────────────────────────────────────────────────
        model.train()
        train_loss = 0.0
        for imgs, labels in train_loader:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(imgs), labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * imgs.size(0)

        train_loss /= len(train_ds)

        # ── Validate ───────────────────────────────────────────────────────
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
                out = model(imgs)
                val_loss += criterion(out, labels).item() * imgs.size(0)
                correct  += (out.argmax(1) == labels).sum().item()
                total    += labels.size(0)

        val_loss /= len(val_ds)
        val_acc   = correct / total
        current_lr = scheduler.get_last_lr()[0]
        scheduler.step()

        row = {'epoch': epoch, 'train_loss': train_loss,
               'val_loss': val_loss, 'val_acc': val_acc}
        history.append(row)

        line = (f'{epoch:<8}{train_loss:<14.4f}{val_loss:<14.4f}'
                f'{val_acc:<12.4f}{current_lr:.6f}')
        log_lines.append(line)
        print(f'  Epoch {epoch:02d}/{EPOCHS} | '
              f'Train Loss: {train_loss:.4f} | '
              f'Val Loss: {val_loss:.4f} | '
              f'Val Acc: {val_acc:.4f}')

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_weights = copy.deepcopy(model.state_dict())

    # Save best checkpoint
    torch.save({
        'model_name'   : model_name,
        'variant'      : VARIANT,
        'state_dict'   : best_weights,
        'best_val_acc' : best_val_acc,
        'class_names'  : CLASS_NAMES,
    }, ckpt_path)

    log_lines += [
        '-' * 70,
        f'Best Val Acc : {best_val_acc:.4f}',
        f'Saved to     : {ckpt_path}',
        f'Finished     : {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}',
    ]
    log_path.write_text('\n'.join(log_lines))
    print(f'  Best val acc: {best_val_acc:.4f} → saved to {ckpt_path}')

    return model, best_weights, history, ckpt_path


print('Training loop defined.')
# Out:
# Training loop defined.

# %% [markdown]
# ## 7. Train All Models

# %%
all_histories   = {}
all_ckpt_paths  = {}

for model_name in MODEL_NAMES:
    model, best_w, history, ckpt = train_model(model_name)
    all_histories[model_name]  = history
    all_ckpt_paths[model_name] = ckpt
    # free GPU memory before next model
    del model
    torch.cuda.empty_cache()

print('\nAll models trained.')
# Out:
# ============================================================
# Training: RESNET50 [leaky]
# ============================================================
#   Epoch 01/30 | Train Loss: 2.1739 | Val Loss: 1.9547 | Val Acc: 0.4400
#   Epoch 02/30 | Train Loss: 1.6117 | Val Loss: 1.7030 | Val Acc: 0.5167
#   Epoch 03/30 | Train Loss: 1.3941 | Val Loss: 1.5627 | Val Acc: 0.5433
#   Epoch 04/30 | Train Loss: 1.2797 | Val Loss: 1.4919 | Val Acc: 0.5600
#   Epoch 05/30 | Train Loss: 1.2089 | Val Loss: 1.4651 | Val Acc: 0.5833
#   [Epoch 6] Backbone unfrozen.
#   Epoch 06/30 | Train Loss: 0.7960 | Val Loss: 0.8972 | Val Acc: 0.7800
#   Epoch 07/30 | Train Loss: 0.5078 | Val Loss: 0.6291 | Val Acc: 0.8433
#   Epoch 08/30 | Train Loss: 0.4028 | Val Loss: 0.9859 | Val Acc: 0.8167
#   Epoch 09/30 | Train Loss: 0.3415 | Val Loss: 0.5895 | Val Acc: 0.8733
#   Epoch 10/30 | Train Loss: 0.2741 | Val Loss: 0.5521 | Val Acc: 0.8667
#   Epoch 11/30 | Train Loss: 0.2509 | Val Loss: 0.7363 | Val Acc: 0.8833
#   Epoch 12/30 | Train Loss: 0.2129 | Val Loss: 0.7300 | Val Acc: 0.8900
#   Epoch 13/30 | Train Loss: 0.1822 | Val Loss: 0.7598 | Val Acc: 0.9200
#   Epoch 14/30 | Train Loss: 0.1566 | Val Loss: 0.4869 | Val Acc: 0.9133
#   Epoch 15/30 | Train Loss: 0.1523 | Val Loss: 0.7176 | Val Acc: 0.9167
#   Epoch 16/30 | Train Loss: 0.1294 | Val Loss: 0.6855 | Val Acc: 0.9133
#   Epoch 17/30 | Train Loss: 0.1146 | Val Loss: 0.6683 | Val Acc: 0.9233
#   Epoch 18/30 | Train Loss: 0.0979 | Val Loss: 0.5763 | Val Acc: 0.9267
#   Epoch 19/30 | Train Loss: 0.0899 | Val Loss: 0.6272 | Val Acc: 0.9267
#   Epoch 20/30 | Train Loss: 0.0837 | Val Loss: 0.6628 | Val Acc: 0.9267
#   Epoch 21/30 | Train Loss: 0.0739 | Val Loss: 0.5389 | Val Acc: 0.9267
#   Epoch 22/30 | Train Loss: 0.0692 | Val Loss: 0.7643 | Val Acc: 0.9267
#   Epoch 23/30 | Train Loss: 0.0637 | Val Loss: 0.5813 | Val Acc: 0.9300
#   Epoch 24/30 | Train Loss: 0.0579 | Val Loss: 0.6718 | Val Acc: 0.9333
#   Epoch 25/30 | Train Loss: 0.0522 | Val Loss: 0.7368 | Val Acc: 0.9300
#   Epoch 26/30 | Train Loss: 0.0505 | Val Loss: 0.7037 | Val Acc: 0.9300
#   Epoch 27/30 | Train Loss: 0.0472 | Val Loss: 0.6804 | Val Acc: 0.9333
#   Epoch 28/30 | Train Loss: 0.0459 | Val Loss: 0.6550 | Val Acc: 0.9300
#   Epoch 29/30 | Train Loss: 0.0440 | Val Loss: 0.7009 | Val Acc: 0.9300
#   Epoch 30/30 | Train Loss: 0.0451 | Val Loss: 0.6616 | Val Acc: 0.9300
#   Best val acc: 0.9333 → saved to /home/adityaraut/Documents/research_paper/leaky/resnet_leaky/resnet50_leaky.pth
#
# ============================================================
# Training: MOBILENET_V3_SMALL [leaky]
# ============================================================
#   Epoch 01/30 | Train Loss: 1.8858 | Val Loss: 1.6820 | Val Acc: 0.4800
#   Epoch 02/30 | Train Loss: 1.3099 | Val Loss: 1.4898 | Val Acc: 0.5267
#   Epoch 03/30 | Train Loss: 1.1897 | Val Loss: 1.3973 | Val Acc: 0.5467
#   Epoch 04/30 | Train Loss: 1.1099 | Val Loss: 1.3354 | Val Acc: 0.5867
#   Epoch 05/30 | Train Loss: 1.0637 | Val Loss: 1.3084 | Val Acc: 0.5900
#   [Epoch 6] Backbone unfrozen.
#   Epoch 06/30 | Train Loss: 0.8746 | Val Loss: 1.0713 | Val Acc: 0.6867
#   Epoch 07/30 | Train Loss: 0.6702 | Val Loss: 0.9026 | Val Acc: 0.7767
#   Epoch 08/30 | Train Loss: 0.5608 | Val Loss: 0.9179 | Val Acc: 0.7933
#   Epoch 09/30 | Train Loss: 0.4776 | Val Loss: 0.7913 | Val Acc: 0.8133
#   Epoch 10/30 | Train Loss: 0.4204 | Val Loss: 0.7452 | Val Acc: 0.8500
#   Epoch 11/30 | Train Loss: 0.3680 | Val Loss: 0.6343 | Val Acc: 0.8467
#   Epoch 12/30 | Train Loss: 0.3229 | Val Loss: 0.6662 | Val Acc: 0.8567
#   Epoch 13/30 | Train Loss: 0.2940 | Val Loss: 0.6301 | Val Acc: 0.8767
#   Epoch 14/30 | Train Loss: 0.2629 | Val Loss: 0.5315 | Val Acc: 0.8867
#   Epoch 15/30 | Train Loss: 0.2395 | Val Loss: 0.5449 | Val Acc: 0.8867
#   Epoch 16/30 | Train Loss: 0.2229 | Val Loss: 0.5742 | Val Acc: 0.8967
#   Epoch 17/30 | Train Loss: 0.1924 | Val Loss: 0.5874 | Val Acc: 0.9000
#   Epoch 18/30 | Train Loss: 0.1837 | Val Loss: 0.5567 | Val Acc: 0.9233
#   Epoch 19/30 | Train Loss: 0.1735 | Val Loss: 0.5312 | Val Acc: 0.9133
#   Epoch 20/30 | Train Loss: 0.1643 | Val Loss: 0.5600 | Val Acc: 0.9167
#   Epoch 21/30 | Train Loss: 0.1547 | Val Loss: 0.5511 | Val Acc: 0.9200
#   Epoch 22/30 | Train Loss: 0.1483 | Val Loss: 0.5145 | Val Acc: 0.9167
#   Epoch 23/30 | Train Loss: 0.1399 | Val Loss: 0.5063 | Val Acc: 0.9133
#   Epoch 24/30 | Train Loss: 0.1313 | Val Loss: 0.5244 | Val Acc: 0.9233
#   Epoch 25/30 | Train Loss: 0.1286 | Val Loss: 0.5065 | Val Acc: 0.9200
#   Epoch 26/30 | Train Loss: 0.1238 | Val Loss: 0.5136 | Val Acc: 0.9233
#   Epoch 27/30 | Train Loss: 0.1227 | Val Loss: 0.5079 | Val Acc: 0.9200
#   Epoch 28/30 | Train Loss: 0.1235 | Val Loss: 0.5030 | Val Acc: 0.9200
#   Epoch 29/30 | Train Loss: 0.1161 | Val Loss: 0.4964 | Val Acc: 0.9200
#   Epoch 30/30 | Train Loss: 0.1125 | Val Loss: 0.4987 | Val Acc: 0.9200
#   Best val acc: 0.9233 → saved to /home/adityaraut/Documents/research_paper/leaky/mnv3_small_leaky/mobilenet_v3_small_leaky.pth
#
# ============================================================
# Training: MOBILENET_V3_LARGE [leaky]
# ============================================================
#   Epoch 01/30 | Train Loss: 1.6473 | Val Loss: 1.4436 | Val Acc: 0.5500
#   Epoch 02/30 | Train Loss: 1.1083 | Val Loss: 1.2483 | Val Acc: 0.6367
#   Epoch 03/30 | Train Loss: 0.9747 | Val Loss: 1.2425 | Val Acc: 0.6367
#   Epoch 04/30 | Train Loss: 0.8985 | Val Loss: 1.1317 | Val Acc: 0.7033
#   Epoch 05/30 | Train Loss: 0.8496 | Val Loss: 1.0838 | Val Acc: 0.7267
#   [Epoch 6] Backbone unfrozen.
#   Epoch 06/30 | Train Loss: 0.6601 | Val Loss: 0.7806 | Val Acc: 0.8167
#   Epoch 07/30 | Train Loss: 0.4465 | Val Loss: 0.7099 | Val Acc: 0.8733
#   Epoch 08/30 | Train Loss: 0.3387 | Val Loss: 0.6435 | Val Acc: 0.8767
#   Epoch 09/30 | Train Loss: 0.2607 | Val Loss: 0.5796 | Val Acc: 0.9133
#   Epoch 10/30 | Train Loss: 0.2184 | Val Loss: 0.4749 | Val Acc: 0.9167
#   Epoch 11/30 | Train Loss: 0.1734 | Val Loss: 0.4620 | Val Acc: 0.9167
#   Epoch 12/30 | Train Loss: 0.1539 | Val Loss: 0.5060 | Val Acc: 0.9233
#   Epoch 13/30 | Train Loss: 0.1403 | Val Loss: 0.5454 | Val Acc: 0.9267
#   Epoch 14/30 | Train Loss: 0.1222 | Val Loss: 0.5834 | Val Acc: 0.9367
#   Epoch 15/30 | Train Loss: 0.1082 | Val Loss: 0.6053 | Val Acc: 0.9267
#   Epoch 16/30 | Train Loss: 0.1004 | Val Loss: 0.4577 | Val Acc: 0.9367
#   Epoch 17/30 | Train Loss: 0.0894 | Val Loss: 0.3996 | Val Acc: 0.9267
#   Epoch 18/30 | Train Loss: 0.0870 | Val Loss: 0.4902 | Val Acc: 0.9300
#   Epoch 19/30 | Train Loss: 0.0824 | Val Loss: 0.4782 | Val Acc: 0.9267
#   Epoch 20/30 | Train Loss: 0.0760 | Val Loss: 0.5049 | Val Acc: 0.9333
#   Epoch 21/30 | Train Loss: 0.0752 | Val Loss: 0.5512 | Val Acc: 0.9367
#   Epoch 22/30 | Train Loss: 0.0725 | Val Loss: 0.5759 | Val Acc: 0.9367
#   Epoch 23/30 | Train Loss: 0.0621 | Val Loss: 0.6253 | Val Acc: 0.9300
#   Epoch 24/30 | Train Loss: 0.0648 | Val Loss: 0.6162 | Val Acc: 0.9333
#   Epoch 25/30 | Train Loss: 0.0573 | Val Loss: 0.6073 | Val Acc: 0.9333
#   Epoch 26/30 | Train Loss: 0.0528 | Val Loss: 0.5823 | Val Acc: 0.9367
#   Epoch 27/30 | Train Loss: 0.0559 | Val Loss: 0.5990 | Val Acc: 0.9333
#   Epoch 28/30 | Train Loss: 0.0537 | Val Loss: 0.5928 | Val Acc: 0.9333
#   Epoch 29/30 | Train Loss: 0.0499 | Val Loss: 0.5984 | Val Acc: 0.9333
#   Epoch 30/30 | Train Loss: 0.0511 | Val Loss: 0.5913 | Val Acc: 0.9333
#   Best val acc: 0.9367 → saved to /home/adityaraut/Documents/research_paper/leaky/mnv3_large_leaky/mobilenet_v3_large_leaky.pth
#
# ============================================================
# Training: EFFICIENTNET_B0 [leaky]
# ============================================================
#   Epoch 01/30 | Train Loss: 2.3448 | Val Loss: 2.1656 | Val Acc: 0.4233
#   Epoch 02/30 | Train Loss: 1.8576 | Val Loss: 1.9063 | Val Acc: 0.4767
#   Epoch 03/30 | Train Loss: 1.6109 | Val Loss: 1.7605 | Val Acc: 0.5000
#   Epoch 04/30 | Train Loss: 1.4704 | Val Loss: 1.6578 | Val Acc: 0.5233
#   Epoch 05/30 | Train Loss: 1.3794 | Val Loss: 1.5972 | Val Acc: 0.5433
#   [Epoch 6] Backbone unfrozen.
#   Epoch 06/30 | Train Loss: 0.8944 | Val Loss: 0.8808 | Val Acc: 0.7433
#   Epoch 07/30 | Train Loss: 0.5496 | Val Loss: 0.6461 | Val Acc: 0.8167
#   Epoch 08/30 | Train Loss: 0.4210 | Val Loss: 0.4869 | Val Acc: 0.8600
#   Epoch 09/30 | Train Loss: 0.3254 | Val Loss: 0.4527 | Val Acc: 0.8833
#   Epoch 10/30 | Train Loss: 0.2726 | Val Loss: 0.4553 | Val Acc: 0.8900
#   Epoch 11/30 | Train Loss: 0.2302 | Val Loss: 0.3718 | Val Acc: 0.9100
#   Epoch 12/30 | Train Loss: 0.1920 | Val Loss: 0.3980 | Val Acc: 0.9067
#   Epoch 13/30 | Train Loss: 0.1672 | Val Loss: 0.4449 | Val Acc: 0.9133
#   Epoch 14/30 | Train Loss: 0.1570 | Val Loss: 0.3670 | Val Acc: 0.9333
#   Epoch 15/30 | Train Loss: 0.1422 | Val Loss: 0.3810 | Val Acc: 0.9300
#   Epoch 16/30 | Train Loss: 0.1281 | Val Loss: 0.4083 | Val Acc: 0.9267
#   Epoch 17/30 | Train Loss: 0.1186 | Val Loss: 0.3887 | Val Acc: 0.9267
#   Epoch 18/30 | Train Loss: 0.1117 | Val Loss: 0.4239 | Val Acc: 0.9267
#   Epoch 19/30 | Train Loss: 0.1032 | Val Loss: 0.3774 | Val Acc: 0.9267
#   Epoch 20/30 | Train Loss: 0.0991 | Val Loss: 0.4385 | Val Acc: 0.9267
#   Epoch 21/30 | Train Loss: 0.0923 | Val Loss: 0.3751 | Val Acc: 0.9267
#   Epoch 22/30 | Train Loss: 0.0836 | Val Loss: 0.3896 | Val Acc: 0.9300
#   Epoch 23/30 | Train Loss: 0.0860 | Val Loss: 0.3828 | Val Acc: 0.9267
#   Epoch 24/30 | Train Loss: 0.0782 | Val Loss: 0.3949 | Val Acc: 0.9267
#   Epoch 25/30 | Train Loss: 0.0792 | Val Loss: 0.3738 | Val Acc: 0.9300
#   Epoch 26/30 | Train Loss: 0.0738 | Val Loss: 0.3943 | Val Acc: 0.9300
#   Epoch 27/30 | Train Loss: 0.0704 | Val Loss: 0.3593 | Val Acc: 0.9300
#   Epoch 28/30 | Train Loss: 0.0704 | Val Loss: 0.3772 | Val Acc: 0.9300
#   Epoch 29/30 | Train Loss: 0.0725 | Val Loss: 0.3686 | Val Acc: 0.9300
#   Epoch 30/30 | Train Loss: 0.0694 | Val Loss: 0.3897 | Val Acc: 0.9300
#   Best val acc: 0.9333 → saved to /home/adityaraut/Documents/research_paper/leaky/efn_leaky/efficientnet_b0_leaky.pth
#
# All models trained.

# %% [markdown]
# ## 8. Training Curves

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 8))

for col, name in enumerate(MODEL_NAMES):
    h = all_histories[name]
    epochs_range = [r['epoch'] for r in h]
    train_losses = [r['train_loss'] for r in h]
    val_losses   = [r['val_loss'] for r in h]
    val_accs     = [r['val_acc'] for r in h]

    ax = axes[0, col]
    ax.plot(epochs_range, train_losses, label='Train')
    ax.plot(epochs_range, val_losses,   label='Val')
    ax.set_title(f'{name}\nLoss')
    ax.legend(fontsize=8)
    ax.set_xlabel('Epoch')

    ax = axes[1, col]
    ax.plot(epochs_range, val_accs, color='green')
    ax.set_title('Val Accuracy')
    ax.set_xlabel('Epoch')
    ax.set_ylim(0, 1)

plt.suptitle('Training Curves — Leaky Dataset', fontsize=14)
plt.tight_layout()
plt.savefig(LEAKY_DIR / 'training_curves.png', dpi=150)
plt.show()

# %% [markdown]
# ## 9. Evaluation on Test Set

# %%
def evaluate_model(model_name: str, ckpt_path: Path):
    ckpt  = torch.load(ckpt_path, map_location=DEVICE)
    model = get_model(model_name, NUM_CLASSES).to(DEVICE)
    model.load_state_dict(ckpt['state_dict'])
    model.eval()

    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs = imgs.to(DEVICE)
            out  = model(imgs)
            probs = torch.softmax(out, dim=1).cpu().numpy()
            preds = out.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels.numpy())
            all_probs.extend(probs)

    all_preds  = np.array(all_preds)
    all_labels = np.array(all_labels)
    all_probs  = np.array(all_probs)

    acc   = (all_preds == all_labels).mean()
    f1    = f1_score(all_labels, all_preds, average='weighted')
    prec  = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    rec   = recall_score(all_labels, all_preds, average='weighted')

    # per-class F1
    per_class_f1 = f1_score(all_labels, all_preds, average=None, zero_division=0)

    # AUC (one-vs-rest)
    labels_bin = label_binarize(all_labels, classes=list(range(NUM_CLASSES)))
    try:
        auc = roc_auc_score(labels_bin, all_probs, multi_class='ovr', average='weighted')
    except Exception:
        auc = float('nan')

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    return {
        'model'        : model_name,
        'accuracy'     : acc,
        'f1_weighted'  : f1,
        'precision'    : prec,
        'recall'       : rec,
        'auc'          : auc,
        'per_class_f1' : per_class_f1,
        'conf_matrix'  : cm,
        'model_obj'    : model,
    }


eval_results = {}
for name in MODEL_NAMES:
    print(f'Evaluating {name}...')
    res = evaluate_model(name, all_ckpt_paths[name])
    eval_results[name] = res
    print(f'  Acc: {res["accuracy"]:.4f} | F1: {res["f1_weighted"]:.4f} | AUC: {res["auc"]:.4f}')
    torch.cuda.empty_cache()
# Out:
# Evaluating resnet50...
# /tmp/ipykernel_5383/4083600585.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt  = torch.load(ckpt_path, map_location=DEVICE)
#   Acc: 0.9307 | F1: 0.9132 | AUC: 0.9826
# Evaluating mobilenet_v3_small...
# /tmp/ipykernel_5383/4083600585.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt  = torch.load(ckpt_path, map_location=DEVICE)
#   Acc: 0.9107 | F1: 0.8938 | AUC: 0.9848
# Evaluating mobilenet_v3_large...
# /tmp/ipykernel_5383/4083600585.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt  = torch.load(ckpt_path, map_location=DEVICE)
#   Acc: 0.9213 | F1: 0.9039 | AUC: 0.9834
# Evaluating efficientnet_b0...
# /tmp/ipykernel_5383/4083600585.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt  = torch.load(ckpt_path, map_location=DEVICE)
#   Acc: 0.9213 | F1: 0.9041 | AUC: 0.9950

# %% [markdown]
# ## 10. Confusion Matrices

# %%
fig, axes = plt.subplots(2, 2, figsize=(22, 18))
axes = axes.flatten()

for i, name in enumerate(MODEL_NAMES):
    cm   = eval_results[name]['conf_matrix']
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)  # normalise
    sns.heatmap(cm_n, ax=axes[i], annot=True, fmt='.2f', cmap='Blues',
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, linewidths=0.3)
    axes[i].set_title(f'{name} — Leaky', fontsize=11)
    axes[i].set_ylabel('True')
    axes[i].set_xlabel('Predicted')
    axes[i].tick_params(axis='x', rotation=45, labelsize=7)
    axes[i].tick_params(axis='y', rotation=0,  labelsize=7)

plt.suptitle('Confusion Matrices — Leaky Dataset', fontsize=14)
plt.tight_layout()
plt.savefig(LEAKY_DIR / 'confusion_matrices.png', dpi=150)
plt.show()

# %% [markdown]
# ## 11. Per-Class F1 Heatmap

# %%
f1_matrix = np.array([eval_results[n]['per_class_f1'] for n in MODEL_NAMES])

fig, ax = plt.subplots(figsize=(16, 5))
sns.heatmap(f1_matrix, annot=True, fmt='.2f', cmap='RdYlGn',
            xticklabels=CLASS_NAMES, yticklabels=MODEL_NAMES,
            vmin=0, vmax=1, linewidths=0.3, ax=ax)
ax.set_title('Per-Class F1 Score — Leaky Dataset', fontsize=13)
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=9)
plt.tight_layout()
plt.savefig(LEAKY_DIR / 'per_class_f1_heatmap.png', dpi=150)
plt.show()

# %% [markdown]
# ## 12. Summary Table

# %%
print(f'\n{"Model":<25}{"Accuracy":<12}{"F1 (W)":<12}{"Precision":<12}{"Recall":<12}{"AUC"}')
print('-' * 75)
for name in MODEL_NAMES:
    r = eval_results[name]
    print(f'{name:<25}{r["accuracy"]:<12.4f}{r["f1_weighted"]:<12.4f}'
          f'{r["precision"]:<12.4f}{r["recall"]:<12.4f}{r["auc"]:.4f}')

# Save summary to each model's log file
for name in MODEL_NAMES:
    r = eval_results[name]
    log_path = SAVE_DIRS[name] / f'{name}_{VARIANT}_metrics.txt'
    existing = log_path.read_text()
    summary_lines = [
        '',
        '=' * 70,
        'TEST SET RESULTS',
        '=' * 70,
        f'Accuracy  : {r["accuracy"]:.4f}',
        f'F1 (W)    : {r["f1_weighted"]:.4f}',
        f'Precision : {r["precision"]:.4f}',
        f'Recall    : {r["recall"]:.4f}',
        f'AUC       : {r["auc"]:.4f}',
        '',
        'Per-Class F1:',
    ]
    for cls, f1 in zip(CLASS_NAMES, r['per_class_f1']):
        summary_lines.append(f'  {cls:<30} {f1:.4f}')
    log_path.write_text(existing + '\n' + '\n'.join(summary_lines))

print('\nMetrics appended to log files.')
# Out:
# Model                    Accuracy    F1 (W)      Precision   Recall      AUC
# ---------------------------------------------------------------------------
# resnet50                 0.9307      0.9132      0.9574      0.9307      0.9826
# mobilenet_v3_small       0.9107      0.8938      0.9270      0.9107      0.9848
# mobilenet_v3_large       0.9213      0.9039      0.9484      0.9213      0.9834
# efficientnet_b0          0.9213      0.9041      0.9487      0.9213      0.9950
#
# Metrics appended to log files.

# %% [markdown]
# ## 13. ONNX Export

# %%
def export_onnx(model_name: str, ckpt_path: Path) -> Path:
    save_dir = SAVE_DIRS[model_name]
    onnx_path = save_dir / f'{model_name}_{VARIANT}_fp32.onnx'

    ckpt  = torch.load(ckpt_path, map_location='cpu')
    model = get_model(model_name, NUM_CLASSES)
    model.load_state_dict(ckpt['state_dict'])
    model.eval()

    dummy = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)

    torch.onnx.export(
        model, dummy, str(onnx_path),
        opset_version=17,
        input_names=['input'],
        output_names=['output'],
        dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
    )

    # Verify
    onnx_model = onnx.load(str(onnx_path))
    onnx.checker.check_model(onnx_model)

    # Numerical check — compare PyTorch vs ONNX on 10 samples
    session = ort.InferenceSession(str(onnx_path),
                                   providers=['CPUExecutionProvider'])
    test_samples = torch.stack([test_ds[i][0] for i in range(10)])
    with torch.no_grad():
        pt_out = torch.softmax(model(test_samples), dim=1).numpy()
    ort_out = session.run(['output'],
                          {'input': test_samples.numpy()})[0]
    ort_out = np.exp(ort_out) / np.exp(ort_out).sum(axis=1, keepdims=True)  # softmax
    max_diff = np.abs(pt_out - ort_out).max()

    fp32_mb = onnx_path.stat().st_size / 1e6
    print(f'  {model_name}: ONNX FP32 = {fp32_mb:.1f} MB | Max diff vs PyTorch = {max_diff:.2e}')
    return onnx_path


onnx_paths = {}
print('Exporting to ONNX...')
for name in MODEL_NAMES:
    onnx_paths[name] = export_onnx(name, all_ckpt_paths[name])

print('ONNX export complete.')
# Out:
# Exporting to ONNX...
# /tmp/ipykernel_5383/647908776.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt  = torch.load(ckpt_path, map_location='cpu')
#   resnet50: ONNX FP32 = 94.1 MB | Max diff vs PyTorch = 1.19e-07
#   mobilenet_v3_small: ONNX FP32 = 6.1 MB | Max diff vs PyTorch = 1.64e-06
#   mobilenet_v3_large: ONNX FP32 = 16.9 MB | Max diff vs PyTorch = 1.79e-07
#   efficientnet_b0: ONNX FP32 = 16.1 MB | Max diff vs PyTorch = 7.66e-07
# ONNX export complete.

# %% [markdown]
# ## 14. INT8 Dynamic Quantisation

# %%
from torch.quantization import quantize_dynamic
from onnxruntime.quantization import quantize_dynamic as onnx_quantize_dynamic, QuantType

def quantize_model(model_name: str, onnx_fp32_path: Path) -> Path:
    save_dir = SAVE_DIRS[model_name]
    onnx_int8_path = save_dir / f'{model_name}_{VARIANT}_int8.onnx'

    onnx_quantize_dynamic(
        model_input=str(onnx_fp32_path),
        model_output=str(onnx_int8_path),
        weight_type=QuantType.QUInt8
    )

    fp32_mb = onnx_fp32_path.stat().st_size / 1e6
    int8_mb = onnx_int8_path.stat().st_size / 1e6
    print(f'  {model_name}: FP32 = {fp32_mb:.1f} MB → INT8 = {int8_mb:.1f} MB '
          f'({100*(1 - int8_mb/fp32_mb):.1f}% reduction)')
    return onnx_int8_path


int8_paths = {}
print('Quantising to INT8...')
for name in MODEL_NAMES:
    int8_paths[name] = quantize_model(name, onnx_paths[name])
# Out:
# Quantising to INT8...
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
#   resnet50: FP32 = 94.1 MB → INT8 = 23.7 MB (74.8% reduction)
#   mobilenet_v3_small: FP32 = 6.1 MB → INT8 = 1.7 MB (72.2% reduction)
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
#   mobilenet_v3_large: FP32 = 16.9 MB → INT8 = 4.4 MB (73.7% reduction)
#   efficientnet_b0: FP32 = 16.1 MB → INT8 = 4.4 MB (72.8% reduction)

# %% [markdown]
# ## 14. INT8 Dynamic Quantisation
# **Note on Performance Sensitivity:**
# As observed in the results, **EfficientNet-B0** and **MobileNetV3-Small** show a catastrophic drop in accuracy after standard dynamic PTQ. This is a well-known architectural sensitivity:
# - **Activations:** Both use Hardswish/Hard-Sigmoid activations which are asymmetric and handled poorly by default calibration.
# - **EfficientNet-B0 SE Blocks:** Squeeze-and-Excitation blocks have highly skewed weight distributions that often collapse under per-tensor 8-bit quantization.
# - **Scale:** Smaller models have less parameter redundancy to buffer quantization noise compared to ResNet50 or MobileNetV3-Large.
#
# **Verification of the fix strategy:**
# The fix involves moving from `quantize_dynamic` (per-tensor) to **Static PTQ with Per-Channel Quantization** and **QDQ format**.
# 1. **Per-channel** handles depthwise convolution weight outliers much better.
# 2. **QDQ (Quantize-Dequantize)** format is more stable for non-ReLU networks as nodes are placed closer to the mathematical operations.
# 3. **Representative Calibration:** Using real training samples (~100-200) instead of random noise is critical for the activation ranges of Hardswish.
#
# The current implementation below uses `quantize_dynamic` which confirms the "disaster" scenario for these specific architectures.

# %% [markdown]
# ## 15. Quantised Model Evaluation

# %%
def evaluate_onnx(model_name: str, onnx_path: Path, label: str):
    session = ort.InferenceSession(str(onnx_path),
                                   providers=['CUDAExecutionProvider',
                                              'CPUExecutionProvider'])
    all_preds, all_labels = [], []

    for imgs, labels in test_loader:
        out = session.run(['output'], {'input': imgs.numpy()})[0]
        preds = out.argmax(axis=1)
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

    all_preds  = np.array(all_preds)
    all_labels = np.array(all_labels)

    acc = (all_preds == all_labels).mean()
    per_class_f1 = f1_score(all_labels, all_preds, average=None, zero_division=0)

    return {'accuracy': acc, 'per_class_f1': per_class_f1}


quant_results = {}
print(f'\n{"Model":<25}{"FP32 Acc":<14}{"INT8 Acc":<14}{"Drop"}')
print('-' * 60)

for name in MODEL_NAMES:
    fp32_acc = eval_results[name]['accuracy']
    q_res    = evaluate_onnx(name, int8_paths[name], 'INT8')
    int8_acc = q_res['accuracy']
    drop     = fp32_acc - int8_acc
    quant_results[name] = q_res

    print(f'{name:<25}{fp32_acc:<14.4f}{int8_acc:<14.4f}{drop:+.4f}')

    # Append quantisation results to log
    log_path = SAVE_DIRS[name] / f'{name}_{VARIANT}_metrics.txt'
    existing = log_path.read_text()
    quant_lines = [
        '',
        '=' * 70,
        'QUANTISATION RESULTS (INT8)',
        '=' * 70,
        f'FP32 Accuracy : {fp32_acc:.4f}',
        f'INT8 Accuracy : {int8_acc:.4f}',
        f'Drop          : {drop:+.4f}',
        '',
        'Per-Class F1 drop after INT8:',
    ]
    for cls, f1_fp32, f1_int8 in zip(
            CLASS_NAMES,
            eval_results[name]['per_class_f1'],
            q_res['per_class_f1']):
        quant_lines.append(f'  {cls:<30} FP32={f1_fp32:.3f}  INT8={f1_int8:.3f}  '
                           f'drop={f1_fp32-f1_int8:+.3f}')
    log_path.write_text(existing + '\n' + '\n'.join(quant_lines))
# Out:
# Model                    FP32 Acc      INT8 Acc      Drop
# ------------------------------------------------------------
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# resnet50                 0.9307        0.9293        +0.0013
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# mobilenet_v3_small       0.9107        0.1227        +0.7880
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# mobilenet_v3_large       0.9213        0.9013        +0.0200
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# efficientnet_b0          0.9213        0.0787        +0.8427

# %% [markdown]
# ## 16. INT8 Accuracy Drop — Per-Class Heatmap

# %%
fp32_f1_matrix  = np.array([eval_results[n]['per_class_f1']    for n in MODEL_NAMES])
int8_f1_matrix  = np.array([quant_results[n]['per_class_f1']   for n in MODEL_NAMES])
drop_matrix     = fp32_f1_matrix - int8_f1_matrix

fig, ax = plt.subplots(figsize=(16, 5))
sns.heatmap(drop_matrix, annot=True, fmt='.2f', cmap='Reds',
            xticklabels=CLASS_NAMES, yticklabels=MODEL_NAMES,
            vmin=0, vmax=0.3, linewidths=0.3, ax=ax)
ax.set_title('Per-Class F1 Drop After INT8 Quantisation — Leaky', fontsize=13)
ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right', fontsize=9)
plt.tight_layout()
plt.savefig(LEAKY_DIR / 'int8_accuracy_drop.png', dpi=150)
plt.show()

print('\nPipeline complete. All artefacts saved to:', LEAKY_DIR)
# Out:
# Pipeline complete. All artefacts saved to: /home/adityaraut/Documents/research_paper/leaky

# %%
# Out:
# efficientnet_b0:
#   input name : input
#   input dtype: tensor(float)
#   input shape: ['batch_size', 3, 224, 224]
#   Validation Accuracy (INT8): 0.9333
#   FP32 ONNX accuracy: 0.9333
#
# mobilenet_v3_small:
#   input name : input
#   input dtype: tensor(float)
#   input shape: ['batch_size', 3, 224, 224]
#   Validation Accuracy (INT8): 0.9233
#   FP32 ONNX accuracy: 0.9233
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 14
#      10     print(f"  FP32 ONNX accuracy: {acc:.4f}")
#      12 # How are you exporting? Show this part of your code
#      13 # It should look like:
# ---> 14 model.eval()
#      15 dummy = torch.randn(1, 3, 224, 224)
#      16 torch.onnx.export(
#      17     model, dummy, str(output_path),
#      18     opset_version=17,          # 17 is safest for EfficientNet/MobileNetV3
#    (...)
#      21     dynamic_axes={'input': {0: 'batch'}, 'output': {0: 'batch'}}
#      22 )
#
# NameError: name 'model' is not defined

# %%
from onnxruntime.quantization import quantize_static, quantize_dynamic, CalibrationDataReader, QuantFormat, QuantType
from onnxruntime.quantization.shape_inference import quant_pre_process

class WheatCalibrationDataReader(CalibrationDataReader):
    def __init__(self, dataloader, input_name='input'):
        self.dataloader = iter(dataloader)
        self.input_name = input_name
        self.counter = 0
        self.max_samples = 100 # ~100-200 samples is ideal

    def get_next(self):
        if self.counter >= self.max_samples:
            return None
        try:
            batch, _ = next(self.dataloader)
            self.counter += batch.size(0)
            return {self.input_name: batch.numpy()}
        except StopIteration:
            return None

def validate_int8(onnx_int8_path, val_loader, input_name):
    """Quick accuracy check after quantization."""
    sess = ort.InferenceSession(str(onnx_int8_path), providers=['CPUExecutionProvider'])
    correct, total = 0, 0
    for batch, labels in val_loader:
        out = sess.run(None, {input_name: batch.numpy()})[0]
        preds = out.argmax(axis=1)
        correct += (preds == labels.numpy()).sum()
        total += len(labels)
    acc = correct / total
    print(f"  Validation Accuracy (INT8): {acc:.4f}")
    return acc

def preprocess_onnx(model_name: str, onnx_path: Path) -> Path:
    """Runs ORT quantization preprocessing (symbolic shape inference)."""
    output_path = onnx_path.parent / f"{onnx_path.stem}_preprocessed.onnx"
    print(f"  Preprocessing: {onnx_path} -> {output_path}")
    quant_pre_process(str(onnx_path), str(output_path))
    return output_path

def quantize_model_static(model_name: str, onnx_fp32_path: Path) -> Path:
    """Implements Static PTQ with Per-Channel quantization and QDQ format.
    Specifically designed for EfficientNet-B0 and MobileNetV3.
    """
    print(f"  [DEBUG] quantize_model_static called with: {onnx_fp32_path}")
    save_dir = SAVE_DIRS[model_name]
    onnx_int8_path = save_dir / f"{model_name}_{VARIANT}_int8_static.onnx"
    
    # 1. Dynamically get input name
    tmp_sess = ort.InferenceSession(str(onnx_fp32_path), providers=['CPUExecutionProvider'])
    input_name = tmp_sess.get_inputs()[0].name
    del tmp_sess

    # 2. Setup Calibration Reader
    calib_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
    dr = WheatCalibrationDataReader(calib_loader, input_name=input_name)

    # 3. Quantize
    quantize_static(
        model_input=str(onnx_fp32_path),
        model_output=str(onnx_int8_path),
        calibration_data_reader=dr,
        quant_format=QuantFormat.QDQ,          
        per_channel=True,                       
        reduce_range=False,                     
        activation_type=QuantType.QUInt8, # Changed to QUInt8 for activations
        weight_type=QuantType.QInt8,
    )

    # 4. Immediate Validation
    validate_int8(onnx_int8_path, val_loader, input_name)

    fp32_mb = onnx_fp32_path.stat().st_size / 1e6
    int8_mb = onnx_int8_path.stat().st_size / 1e6
    print(f"  {model_name} [STATIC]: FP32 = {fp32_mb:.1f} MB → INT8 = {int8_mb:.1f} MB "
          f"({100*(1 - int8_mb/fp32_mb):.1f}% reduction)")
    
    return onnx_int8_path

def quantize_model_dynamic_advanced(model_name: str, onnx_fp32_path: Path) -> Path:
    """Fallback: implements Dynamic PTQ with Per-Channel quantization.
    Note: We use QUInt8 for weights to avoid ConvInteger errors with per_channel=True 
    on some CPU backends if QInt8 is not supported for that specific node.
    """
    save_dir = SAVE_DIRS[model_name]
    onnx_int8_path = save_dir / f"{model_name}_{VARIANT}_int8_dynamic_fixed.onnx"
    
    quantize_dynamic(
        model_input=str(onnx_fp32_path),
        model_output=str(onnx_int8_path),
        weight_type=QuantType.QUInt8, # Changed to QUInt8 to resolve ConvInteger implementation error
        per_channel=True,
    )
    
    tmp_sess = ort.InferenceSession(str(onnx_int8_path), providers=['CPUExecutionProvider'])
    input_name = tmp_sess.get_inputs()[0].name
    validate_int8(onnx_int8_path, val_loader, input_name)
    
    fp32_mb = onnx_fp32_path.stat().st_size / 1e6
    int8_mb = onnx_int8_path.stat().st_size / 1e6
    print(f"  {model_name} [DYNAMIC]: FP32 = {fp32_mb:.1f} MB -> INT8 = {int8_mb:.1f} MB "
          f"({100*(1 - int8_mb/fp32_mb):.1f}% reduction)")
    return onnx_int8_path

# Run static quantization for the problematic models
print("Running Advanced Static Quantization (Per-Channel + QDQ)...")
int8_static_paths = {}
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    print(f"\n--- {name} ---")
    # Preprocess first
    preprocessed_path = preprocess_onnx(name, onnx_paths[name])
    print(f"  Preprocessed exists: {preprocessed_path.exists()}")
    
    # Feed the preprocessed file into quantizer
    int8_static_paths[name] = quantize_model_static(name, preprocessed_path)

# --- Evaluation on Test Set ---
def evaluate_onnx_static(model_name: str, onnx_path: Path):
    session = ort.InferenceSession(str(onnx_path),
                                   providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
    input_name = session.get_inputs()[0].name
    all_preds, all_labels = [], []

    for imgs, labels in test_loader:
        out = session.run(None, {input_name: imgs.numpy()})[0]
        preds = out.argmax(axis=1)
        all_preds.extend(preds)
        all_labels.extend(labels.numpy())

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    acc = (all_preds == all_labels).mean()
    per_class_f1 = f1_score(all_labels, all_preds, average=None, zero_division=0)
    f1_weighted = f1_score(all_labels, all_preds, average='weighted')

    return {'accuracy': acc, 'f1_weighted': f1_weighted, 'per_class_f1': per_class_f1}

print(f'\n{"Model (Static INT8)":<25}{"Accuracy":<14}{"F1 (W)":<14}{"Drop vs FP32"}')
print('-' * 70)

static_quant_results = {}
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    fp32_acc = eval_results[name]['accuracy']
    res = evaluate_onnx_static(name, int8_static_paths[name])
    static_quant_results[name] = res
    drop = fp32_acc - res['accuracy']
    
    print(f'{name:<25}{res["accuracy"]:<14.4f}{res["f1_weighted"]:<14.4f}{drop:+.4f}')

# fallback if MobileNetV3-Small or EfficientNet-B0 is still dead
# EfficientNet-B0 was 0.38 which is < 0.5, so we apply fallback to it too
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    if static_quant_results[name]['accuracy'] < 0.5:
        print(f"\n{name} static PTQ failed (<50% acc), falling back to advanced dynamic quantization...")
        int8_static_paths[name] = quantize_model_dynamic_advanced(
            name, onnx_paths[name]
        )
        # Re-evaluate the fallback result
        res = evaluate_onnx_static(name, int8_static_paths[name])
        static_quant_results[name] = res
        drop = eval_results[name]['accuracy'] - res['accuracy']
        print(f'{name} (Dynamic Fallback) {res["accuracy"]:<6.4f}  F1 (W): {res["f1_weighted"]:.4f}')

# Save results to log
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    res = static_quant_results[name]
    fp32_acc = eval_results[name]['accuracy']
    drop = fp32_acc - res['accuracy']
    
    log_path = SAVE_DIRS[name] / f'{name}_{VARIANT}_metrics.txt'
    existing = log_path.read_text()
    
    strategy = "STATIC (QDQ + Per-Channel + QUInt8)"
    # Check if we used the dynamic fallback path
    if "dynamic_fixed" in str(int8_static_paths[name]):
        strategy = "DYNAMIC FALLBACK (Per-Channel + QUInt8 Weights)"

    log_lines = [
        '',
        '=' * 70,
        f'ADVANCED QUANTISATION RESULTS (INT8)',
        '=' * 70,
        f'Strategy       : {strategy}',
        f'FP32 Accuracy  : {fp32_acc:.4f}',
        f'INT8 Accuracy  : {res["accuracy"]:.4f}',
        f'F1 (Weighted)  : {res["f1_weighted"]:.4f}',
        f'Acc Drop       : {drop:+.4f}',
        '',
        'Per-Class F1 (Advanced INT8):',
    ]
    for cls, f1 in zip(CLASS_NAMES, res['per_class_f1']):
        log_lines.append(f'  {cls:<30} {f1:.4f}')
    
    log_path.write_text(existing + '\n' + '\n'.join(log_lines))
# Out:
# Running Advanced Static Quantization (Per-Channel + QDQ)...
#
# --- efficientnet_b0 ---
#   Preprocessing: /home/adityaraut/Documents/research_paper/leaky/efn_leaky/efficientnet_b0_leaky_fp32.onnx -> /home/adityaraut/Documents/research_paper/leaky/efn_leaky/efficientnet_b0_leaky_fp32_preprocessed.onnx
#   Preprocessed exists: True
#   [DEBUG] quantize_model_static called with: /home/adityaraut/Documents/research_paper/leaky/efn_leaky/efficientnet_b0_leaky_fp32_preprocessed.onnx
#   Validation Accuracy (INT8): 0.3967
#   efficientnet_b0 [STATIC]: FP32 = 16.1 MB → INT8 = 4.9 MB (69.6% reduction)
#
# --- mobilenet_v3_small ---
#   Preprocessing: /home/adityaraut/Documents/research_paper/leaky/mnv3_small_leaky/mobilenet_v3_small_leaky_fp32.onnx -> /home/adityaraut/Documents/research_paper/leaky/mnv3_small_leaky/mobilenet_v3_small_leaky_fp32_preprocessed.onnx
#   Preprocessed exists: True
#   [DEBUG] quantize_model_static called with: /home/adityaraut/Documents/research_paper/leaky/mnv3_small_leaky/mobilenet_v3_small_leaky_fp32_preprocessed.onnx
#   Validation Accuracy (INT8): 0.1133
#   mobilenet_v3_small [STATIC]: FP32 = 6.2 MB → INT8 = 1.9 MB (69.4% reduction)
#
# Model (Static INT8)      Accuracy      F1 (W)        Drop vs FP32
# ----------------------------------------------------------------------
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# efficientnet_b0          0.3480        0.3767        +0.5733
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# mobilenet_v3_small       0.1053        0.0626        +0.8053
#
# efficientnet_b0 static PTQ failed (<50% acc), falling back to advanced dynamic quantization...
#   Validation Accuracy (INT8): 0.0533
#   efficientnet_b0 [DYNAMIC]: FP32 = 16.1 MB -> INT8 = 4.4 MB (72.8% reduction)
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
# efficientnet_b0 (Dynamic Fallback) 0.0787  F1 (W): 0.0347
#
# mobilenet_v3_small static PTQ failed (<50% acc), falling back to advanced dynamic quantization...
#   Validation Accuracy (INT8): 0.1267
#   mobilenet_v3_small [DYNAMIC]: FP32 = 6.1 MB -> INT8 = 1.7 MB (72.1% reduction)
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# mobilenet_v3_small (Dynamic Fallback) 0.1227  F1 (W): 0.0645

# %%
# Verify FP32 ONNX is actually correct before touching quantization
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    sess = ort.InferenceSession(str(onnx_paths[name]), providers=['CPUExecutionProvider'])
    inp = sess.get_inputs()[0]
    print(f"\n{name}:")
    print(f"  input name : {inp.name}")
    print(f"  input dtype: {inp.type}")
    print(f"  input shape: {inp.shape}")
    acc = validate_int8(onnx_paths[name], val_loader, inp.name)
    print(f"  FP32 ONNX accuracy: {acc:.4f}")

# Example of how the export was performed in the previous cell (Cell 27)
# Note: 'model' is not globally defined because we 'del' it in the loop to save memory.
"""
def export_onnx(model_name: str, ckpt_path: Path) -> Path:
    save_dir = SAVE_DIRS[model_name]
    onnx_path = save_dir / f'{model_name}_{VARIANT}_fp32.onnx'

    ckpt  = torch.load(ckpt_path, map_location='cpu')
    model = get_model(model_name, NUM_CLASSES)
    model.load_state_dict(ckpt['state_dict'])
    model.eval()

    dummy = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)

    torch.onnx.export(
        model, dummy, str(onnx_path),
        opset_version=17,
        input_names=['input'],
        output_names=['output'],
        dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
    )
    ...
"""
# Out:
# efficientnet_b0:
#   input name : input
#   input dtype: tensor(float)
#   input shape: ['batch_size', 3, 224, 224]
#   Validation Accuracy (INT8): 0.9333
#   FP32 ONNX accuracy: 0.9333
#
# mobilenet_v3_small:
#   input name : input
#   input dtype: tensor(float)
#   input shape: ['batch_size', 3, 224, 224]
#   Validation Accuracy (INT8): 0.9233
#   FP32 ONNX accuracy: 0.9233
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 14
#      10     print(f"  FP32 ONNX accuracy: {acc:.4f}")
#      12 # How are you exporting? Show this part of your code
#      13 # It should look like:
# ---> 14 model.eval()
#      15 dummy = torch.randn(1, 3, 224, 224)
#      16 torch.onnx.export(
#      17     model, dummy, str(output_path),
#      18     opset_version=17,          # 17 is safest for EfficientNet/MobileNetV3
#    (...)
#      21     dynamic_axes={'input': {0: 'batch'}, 'output': {0: 'batch'}}
#      22 )
#
# NameError: name 'model' is not defined

# %%
import torch
from torch.ao.quantization import get_default_qconfig_mapping
from torch.ao.quantization.quantize_fx import prepare_fx, convert_fx

def quantize_pytorch_fx(model_name: str, ckpt_path: Path):
    """
    Implements PyTorch FX Graph Mode Quantization.
    This is generally more robust for modern architectures like EfficientNet and MobileNetV3
    as it can handle custom activation functions (Hardswish) and complex connectivity (SE blocks).
    """
    print(f"\n--- {model_name} (PyTorch FX Quantization) ---")
    
    # 1. Load model and weights
    ckpt = torch.load(ckpt_path, map_location='cpu')
    model = get_model(model_name, NUM_CLASSES)
    model.load_state_dict(ckpt['state_dict'])
    model.eval()

    # 2. Define quantization configuration
    # Use 'x86' (fbgemm) for server/desktop or 'qnnpack' for mobile/ARM
    qconfig_mapping = get_default_qconfig_mapping("fbgemm")
    
    # 3. Prepare for quantization (Pattern matching + Observer insertion)
    example_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
    prepared_model = prepare_fx(model, qconfig_mapping, example_input)

    # 4. Calibration (Run real data through the observers)
    print("  Calibrating...")
    with torch.no_grad():
        count = 0
        for imgs, _ in train_loader:
            prepared_model(imgs)
            count += imgs.size(0)
            if count >= 200: # Sufficient for calibration
                break

    # 5. Convert to quantized integer model
    quantized_model = convert_fx(prepared_model)
    print("  Conversion complete.")

    # 6. Evaluation (Validation Set)
    correct, total = 0, 0
    with torch.no_grad():
        for imgs, labels in val_loader:
            out = quantized_model(imgs)
            preds = out.argmax(axis=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    
    acc = correct / total
    print(f"  PyTorch FX INT8 Accuracy (Val): {acc:.4f}")

    # 7. Export to ONNX (QDQ format)
    save_dir = SAVE_DIRS[model_name]
    onnx_path = save_dir / f"{model_name}_{VARIANT}_int8_pytorch_fx.onnx"
    
    try:
        torch.onnx.export(
            quantized_model, example_input, str(onnx_path),
            opset_version=17,
            input_names=['input'],
            output_names=['output'],
            dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
        )
        print(f"  Exported to: {onnx_path.name}")
    except Exception as e:
        print(f"  ONNX Export failed for {model_name} (FX): {e}")
        print("  Recommendation: Benchmark this model using PyTorch/TorchScript directly.")

    return quantized_model, onnx_path

# Execute for the problematic models
fx_quant_results = {}
for name in ['efficientnet_b0', 'mobilenet_v3_small']:
    q_model, q_path = quantize_pytorch_fx(name, all_ckpt_paths[name])
    fx_quant_results[name] = {'model': q_model, 'onnx_path': q_path}
# Out:
# --- efficientnet_b0 (PyTorch FX Quantization) ---
# /tmp/ipykernel_5383/2951792313.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location='cpu')
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
#   Calibrating...
#   Conversion complete.
#   PyTorch FX INT8 Accuracy (Val): 0.5333
#   Exported to: efficientnet_b0_leaky_int8_pytorch_fx.onnx
#
# --- mobilenet_v3_small (PyTorch FX Quantization) ---
# /tmp/ipykernel_5383/2951792313.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(ckpt_path, map_location='cpu')
# /home/adityaraut/miniconda3/envs/agent/lib/python3.10/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
#   Calibrating...
#   Conversion complete.
#   PyTorch FX INT8 Accuracy (Val): 0.1033
#   Exported to: mobilenet_v3_small_leaky_int8_pytorch_fx.onnx
